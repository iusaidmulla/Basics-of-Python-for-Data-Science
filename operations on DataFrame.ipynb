# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_json(r'https://raw.githubusercontent.com/Sreemanto/DSP-55/main/analyst_in_tool.json').iloc[:,0]
df
# Out:
# 0    [{'id': 3335, 'resourceId': 46, 'day': 0, 'val...
# 1    [{'id': 3300, 'resourceId': 49, 'day': 0, 'val...
# Name: availability, dtype: object

# %%
pd.DataFrame(df[0])
# Out:
#       id  resourceId  day  value  isActive  shift
# 0   3335          46    0    0.0     False      1
# 1   3343          46    0    0.0     False      2
# 2   3350          46    0    0.0     False      3
# 3   3337          46    1    8.0     False      1
# 4   3344          46    1    0.0     False      2
# 5   3351          46    1    0.0     False      3
# 6   3338          46    2    8.0     False      1
# 7   3346          46    2    0.0     False      2
# 8   3352          46    2    0.0     False      3
# 9   3339          46    3    8.0     False      1
# 10  3353          46    3    0.0     False      3
# 11  3355          46    3    0.0     False      2
# 12  3340          46    4    8.0     False      1
# 13  3347          46    4    0.0     False      2
# 14  3354          46    4    0.0     False      3
# 15  3336          46    5    8.0     False      3
# 16  3341          46    5    8.0     False      1
# 17  3348          46    5    0.0     False      2
# ...

# %%
df_details = pd.read_json(r'https://raw.githubusercontent.com/Sreemanto/DSP-55/main/analyst_in_tool.json').iloc[:,1:]
df_details
# Out:
#    numberOfCampaignGroupCapabilities  isActive  id          name  expiryDate  \
# 0                                  0     False  46            a1         NaN
# 1                                  0     False  49  Test_Analyst         NaN
#
#    resourceType  extWeeklyWorkingHours  extStatus
# 0             0                     56          1
# 1             0                     32          1

# %%
df = pd.read_json(r'https://raw.githubusercontent.com/Sreemanto/DSP-55/main/analyst_in_tool.json').iloc[:,0]

df_resource = pd.DataFrame()
for i in df.values:
    temp_df = pd.DataFrame(i)
    df_resource = pd.concat([df_resource,temp_df])
df_resource.reset_index()
# Out:
#     index    id  resourceId  day  value  isActive  shift
# 0       0  3335          46    0    0.0     False      1
# 1       1  3343          46    0    0.0     False      2
# 2       2  3350          46    0    0.0     False      3
# 3       3  3337          46    1    8.0     False      1
# 4       4  3344          46    1    0.0     False      2
# 5       5  3351          46    1    0.0     False      3
# 6       6  3338          46    2    8.0     False      1
# 7       7  3346          46    2    0.0     False      2
# 8       8  3352          46    2    0.0     False      3
# 9       9  3339          46    3    8.0     False      1
# 10     10  3353          46    3    0.0     False      3
# 11     11  3355          46    3    0.0     False      2
# 12     12  3340          46    4    8.0     False      1
# 13     13  3347          46    4    0.0     False      2
# 14     14  3354          46    4    0.0     False      3
# ...

# %%
df['availability'][0][0]
# Out:
# {'id': 3335,
#  'resourceId': 46,
#  'day': 0,
#  'value': 0.0,
#  'isActive': False,
#  'shift': 1}

# %%
import json

with open("parameters.json",'r') as f:
    params = json.load(f)
params
# Out:
# {'filename': 'Resources.csv',
#  'filepath': "'https://raw.githubusercontent.com/Sreemanto/DSP-55/main/analyst_in_tool.json"}
